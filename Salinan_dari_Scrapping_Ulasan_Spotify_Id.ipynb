# %% [markdown]
# <a href="https://colab.research.google.com/github/Rosma640/Scrapping/blob/main/Salinan_dari_Scrapping_Ulasan_Spotify_Id.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install google-play-scraper

# %%
from google_play_scraper import Sort, reviews
from google_play_scraper import app
import pandas as pd
import numpy as np

# %%
result, continuation_token = reviews(
    'com.spotify.music',
    lang='id', #bahasa
    country='id', #negara
    sort=Sort.MOST_RELEVANT, #sorting yg paling relevan
    count=1000, #jumlah dataset
    filter_score_with= None  #Isi dengan 1, 2, 3, 4, 5 None jika ingin bercampur
)

# %%
# Dataframe dengan nama
data = pd.DataFrame(np.array(result),columns=['review'])
data = data.join(pd.DataFrame(data.pop('review').tolist()))
data.head()
# Out:
#                                reviewId         userName  \
# 0  9446c441-02b6-497b-8502-3e8566a25c96  siera frombaduy
# 1  7158de3e-3e28-49ff-9953-23362f86295f  Clara Christina
# 2  9178e39d-4807-407b-bda5-34cf3b1fa5da             Desi
# 3  ffbb194b-d23a-4519-ab06-d19cd0c69651   Rez Zill (Rez)
# 4  d2359ddb-a97c-4ac8-85d9-beb165311847     nanang rusno
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2  https://play-lh.googleusercontent.com/a-/ALV-U...
# 3  https://play-lh.googleusercontent.com/a/ACg8oc...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                              content  score  thumbsUpCount  \
# 0  Munculnya iklan sebetulnya itu adalah wajar, t...      1            350
# 1  Menurut saya sangat perfect tapi setiapa saya,...      3            149
# ...

# %%
len(data)
# Out:
# 1000

# %%
data = data[['content', 'score']]
data.head()
# Out:
#                                              content  score
# 0  Munculnya iklan sebetulnya itu adalah wajar, t...      1
# 1  Menurut saya sangat perfect tapi setiapa saya,...      3
# 2  Masih suka dengerin lagu pake spotify, tapi ke...      3
# 3  Bintang 3! Alasan: kita gak bisa loncat loncat...      3
# 4  Spotify musik dengan penjedaan iklan itu bagus...      4

# %%
data.to_csv("Ulasan Spotify 1000 Data.csv", index = False  , encoding='utf-8')

# %%
dataSpotify = pd.read_csv('/content/Ulasan Spotify 1000 Data.csv')
dataSpotify.head()
# Out:
#                                              content  score
# 0  Munculnya iklan sebetulnya itu adalah wajar, t...      1
# 1  Menurut saya sangat perfect tapi setiapa saya,...      3
# 2  Masih suka dengerin lagu pake spotify, tapi ke...      3
# 3  Bintang 3! Alasan: kita gak bisa loncat loncat...      3
# 4  Spotify musik dengan penjedaan iklan itu bagus...      4

# %%
data = data.rename(columns={'content': 'ulasan', 'score': 'rating'}) #mengganti nama fitur
data.head()
# Out:
#                                               ulasan  rating
# 0  Munculnya iklan sebetulnya itu adalah wajar, t...       1
# 1  Menurut saya sangat perfect tapi setiapa saya,...       3
# 2  Masih suka dengerin lagu pake spotify, tapi ke...       3
# 3  Bintang 3! Alasan: kita gak bisa loncat loncat...       3
# 4  Spotify musik dengan penjedaan iklan itu bagus...       4
