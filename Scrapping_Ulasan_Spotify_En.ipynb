# %% [markdown]
# <a href="https://colab.research.google.com/github/Rosma640/Scrapping/blob/main/Scrapping_Ulasan_Spotify_En.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install google-play-scraper

# %%
from google_play_scraper import Sort, reviews
from google_play_scraper import app
import pandas as pd
import numpy as np

# %%
result, continuation_token = reviews(
    'com.spotify.music',
    lang='en', #bahasa
    country='id', #negara
    sort=Sort.MOST_RELEVANT, #sorting yg paling relevan
    count=1000, #jumlah dataset
    filter_score_with= None  #Isi dengan 1, 2, 3, 4, 5 None jika ingin bercampur
)

# %%
# Dataframe dengan nama
data = pd.DataFrame(np.array(result),columns=['review'])
data = data.join(pd.DataFrame(data.pop('review').tolist()))
data.head()
# Out:
#                                reviewId               userName  \
# 0  03830de5-3f44-4139-97ef-c38ac6bc23a4  Kanaya Sahira hardewa
# 1  b4c06540-8817-44fb-86d7-8b06f1b74604          Blue Sapphire
# 2  7c46f7fe-ef05-4c3a-aa57-54e7c45e8faa         Tjandra Matair
# 3  a52ca291-44ff-4810-bd8c-ebd64a5c9bb2             Lucky Chin
# 4  ed7a453c-b920-4be9-942c-ed9840711bde       Albert Robbinson
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2  https://play-lh.googleusercontent.com/a-/ALV-U...
# 3  https://play-lh.googleusercontent.com/a/ACg8oc...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                              content  score  thumbsUpCount  \
# 0  Literally the worst downgrade. I remember that...      1              9
# 1  Subscription REQUIRED!!! I have been using thi...      3             75
# ...

# %%
len(data)
# Out:
# 1000

# %%
data = data[['content', 'score']]
data.head()
# Out:
#                                              content  score
# 0  Literally the worst downgrade. I remember that...      1
# 1  Subscription REQUIRED!!! I have been using thi...      3
# 2  I really liked this app but the problem is tha...      4
# 3  Hello, today I’m going to rate one of my apps,...      4
# 4  The "Explore your genres" is freaking annoying...      1

# %%
data.to_csv("Ulasan Spotify 1000 Data2.csv", index = False  , encoding='utf-8')

# %%
dataSpotify = pd.read_csv('/content/Ulasan Spotify 1000 Data2.csv')
dataSpotify.head()
# Out:
#                                              content  score
# 0  Literally the worst downgrade. I remember that...      1
# 1  Subscription REQUIRED!!! I have been using thi...      3
# 2  I really liked this app but the problem is tha...      4
# 3  Hello, today I’m going to rate one of my apps,...      4
# 4  The "Explore your genres" is freaking annoying...      1

# %%
data = data.rename(columns={'content': 'ulasan', 'score': 'label'}) #mengganti nama fitur
data.head()
# Out:
#                                               ulasan  label
# 0  Literally the worst downgrade. I remember that...      1
# 1  Subscription REQUIRED!!! I have been using thi...      3
# 2  I really liked this app but the problem is tha...      4
# 3  Hello, today I’m going to rate one of my apps,...      4
# 4  The "Explore your genres" is freaking annoying...      1
